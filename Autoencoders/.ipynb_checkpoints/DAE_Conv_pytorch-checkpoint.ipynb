# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import skimage.transform as trf
from utiles import *

# %%
import os
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms

# %%
target = data_loader("data/lfwcrop_grey",shape=(64, 64))

# %%
n_ratio = .1
data = target + n_ratio*np.random.normal(0, 1, target.shape)
data = np.clip(data, a_max=1, a_min=0)

x_train, x_test, y_train, y_test = train_test_split( data, target, test_size=.25, random_state=15)

# %%
plot_n_faces(x_train, y_train, 2, h_size=4)

# %% [markdown]
# ## Model

# %%
class Autoencoder(nn.Module):
    def __init__(self, img_shape=(28, 28)):
        super(Autoencoder, self).__init__()
        w, h = img_shape
        self.c1 = nn.Conv2d( 1, 16, 3, padding=1, stride=1 )
        self.c2 = nn.Conv2d( 16, 32, 3, padding=1, stride=1 )
        self.c3 = nn.Conv2d( 32, 64, 3, padding=1, stride=1 )

        self.ct1 = nn.ConvTranspose2d( 64, 32, 3, padding=1, stride=2 )
        self.ct2 = nn.ConvTranspose2d( 32, 16, 3, padding=1, stride=2 )
        self.ct3 = nn.ConvTranspose2d( 16, 1, 3, padding=1, stride=2 )

    def encode( self, x ):
        x = nn.ReLU(True)( self.c1( x ) )
        x = nn.MaxPool2d( kernel_size=2, stride=2 )( x )
        x = nn.ReLU(True)( self.c2( x ) )
        x = nn.MaxPool2d( kernel_size=2, stride=2 )( x )
        x = nn.ReLU(True)( self.c3( x ) )
        x = nn.MaxPool2d( kernel_size=2, stride=2 )( x )
        return x

    def decode( self, code ):
        out_s = np.array(code.size())[-2:]*2
        print( out_s )
        x = self.ct1( code, output_size=out_s )
        x = nn.ReLU( True )( x )
        out_s = out_s*2
        x = self.ct2( x, output_size=out_s )
        x = nn.ReLU( True )( x )
        out_s = out_s*2
        x = self.ct3( x, output_size=out_s )
        x = nn.Tanh()( x )
        return x
    
    def forward(self, x):
        code = self.encode( x )
        rec = self.decode( code )
        return rec

# %%
model = Autoencoder(img_shape=(64, 64))
model.double()
# Out:
# Autoencoder(
#   (c1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (ct1): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (ct2): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (ct3): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam( model.parameters(), lr=0.0001 )

# %%
x_train_raw, x_train_dl = to_tensor( x_train, b_size=50 )
y_train_raw, y_train_dl = to_tensor( y_train, b_size=50 )

# %%
n_epochs = 10
for e in range( n_epochs ):
    for d, t in zip(x_train_dl, y_train_dl):
        optimizer.zero_grad()
        img = d[0]
        img = Variable(img)

        trg = t[0]
        trg = Variable(trg)
        
        output = model(img)
        loss = criterion(output, trg)
        loss.backward()
        optimizer.step()

    print("epoch [{}/{}], loss:{:.4f}".format(e + 1, n_epochs, loss.item()))
# Out:
# --------------------------------------------------------------------------
# ValueError                               Traceback (most recent call last)
# <ipython-input-98-94a9dc0860d7> in <module>()
#       9         trg = Variable(trg)
#      10
# ---> 11         output = model(img)
#      12         loss = criterion(output, trg)
#      13         loss.backward()
#
# /home/samuel/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# <ipython-input-94-6fe51b85cdd6> in forward(self, x)
#      35     def forward(self, x):
#      36         code = self.encode( x )
# ---> 37         rec = self.decode( code )
#      38         return rec
#
# <ipython-input-94-6fe51b85cdd6> in decode(self, code)
#      26         x = nn.ReLU( True )( x )
#      27         out_s = out_s*2
# ---> 28         x = self.ct2( code, output_size=out_s )
#      29         x = nn.ReLU( True )( x )
#      30         out_s = out_s*2
#
# /home/samuel/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /home/samuel/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input, output_size)
#     685
#     686     def forward(self, input, output_size=None):
# --> 687         output_padding = self._output_padding(input, output_size)
#     688         return F.conv_transpose2d(
#     689             input, self.weight, self.bias, self.stride, self.padding,
#
# /home/samuel/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py in _output_padding(self, input, output_size)
#     458                     "requested an output size of {}, but valid sizes range "
#     459                     "from {} to {} (for an input of {})").format(
# --> 460                         output_size, min_sizes, max_sizes, input.size()[2:]))
#     461
#     462         return tuple([output_size[d] - min_sizes[d] for d in range(k)])
#
# ValueError: requested an output size of [32, 32], but valid sizes range from [15, 15] to [16, 16] (for an input of torch.Size([8, 8]))

# %%
torch.save(model.state_dict(), "pesos/pytorch_dae_conv.h5")

# %%
x_test_r, x_test_dl = to_tensor( x_test, b_size=50)
y_test_r, y_test_dl = to_tensor(y_test, b_size=50)

# %%
d_data = next( iter(x_test_dl) )

# %%
predicted = model( Variable(d_data[0])).data.numpy()

ddata = x_test[:50]
ttarget = y_test[:50]
predicted = predicted.reshape( predicted.shape[0], 64, 64 )
ddata.shape, ttarget.shape, predicted.shape
# Out:
# ((50, 64, 64), (50, 64, 64), (50, 64, 64))

# %%
plot_n_faces(ddata, ttarget, 5, predicted)

# %%
from skimage.filters import median
from skimage.morphology import selem
s = selem.square(3)
# i = np.random.randint(x_test.shape[0])
i = np.random.randint( 50 )
img = median( x_test[i], s )
f = plt.figure()
ax = f.add_subplot(1,2,1)
ax.imshow(x_test[i], cmap=plt.cm.gray)
ax = f.add_subplot(1,2,2)
ax.imshow(img, cmap=plt.cm.gray)
plt.show()
# Out:
# /usr/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
